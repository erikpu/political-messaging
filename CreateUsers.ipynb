# %% [markdown]
# # CreateUsers.ipynb
#
# ### This notebook defines the users, sets properties and writes them to a text file for further usage.
#
# Author: Erik Puijk <br>
# Date  : February 3, 2022

# %%
import json

# %%
def write_users():
    """ This function defines users with their Twitter handles, sets properties and writes this to a text file."""
    
    users = {
                "VVD": {
                    "followers": 249822
                },
                "markrutte": {
                    "followers": 183864
                },
                "D66": {
                    "followers": 214091
                },
                "SigridKaag": {
                    "followers": 66032
                },
                "geertwilderspvv": {
                    "followers": 857106
                },
                "cdavandaag": {
                    "followers": 54323
                },
                "WBHoekstra": {
                    "followers": 44305
                },
                "SPnl": {
                    "followers": 62559
                },
                "MarijnissenL": {
                    "followers": 48354
                },
                "PvdA": {
                    "followers": 153934
                },
                "PloumenLilianne": {
                    "followers": 13417
                },
                "groenlinks": {
                    "followers": 143157
                },
                "jesseklaver": {
                    "followers": 283408
                },
                "fvdemocratie": {
                    "followers": 87761
                },
                "thierrybaudet": {
                    "followers": 251527
                },
                "PartijvdDieren": {
                    "followers": 51808
                },
                "estherouwehand": {
                    "followers": 33358
                },
                "christenunie": {
                    "followers": 35576
                },
                "gertjansegers": {
                    "followers": 56971
                },
                "VoltNederland": {
                    "followers": 14285
                },
                "DassenLaurens": {
                    "followers": 6200
                },
                "JuisteAntwoord": {
                    "followers": 8545
                },
                "Eerdmans": {
                    "followers": 29778
                },
                "SGPnieuws": {
                    "followers": 17410
                },
                "keesvdstaaij": {
                    "followers": 87446
                },
                "DenkNL": {
                    "followers": 16749
                },
                "F_azarkan": {
                    "followers": 14531
                },
                "50pluspartij": {
                    "followers": 6773
                },
                "LianedenHaan": {
                    "followers": 2963
                },
                "BoerBurgerB": {
                    "followers": 9266
                },
                "lientje1967": {
                    "followers": 45145
                },
                "PolitiekBIJ1": {
                    "followers": 10231
                },
                "SylvanaBIJ1": {
                    "followers": 15253
                }
    }

    with open('source/users.txt', 'w') as convert_file:
         convert_file.write(json.dumps(users))
